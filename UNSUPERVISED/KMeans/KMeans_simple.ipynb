# %%
# KMeans

# %%
from sklearn.datasets import make_blobs

X,y = make_blobs(n_samples=1000,n_features=2,cluster_std=0.6,centers=3)

# %%
from sklearn.cluster import KMeans

kmeans = KMeans()

kmeans.fit(X)
# Out:
# KMeans()

# %%
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

print("Cluster labels:", labels[:10])  # first 10 labels
print("Centroids:\n", centroids)
# Out:
# Cluster labels: [3 4 6 6 2 1 4 5 3 4]
# Centroids:
#  [[-3.56815431 -6.18852087]
#  [ 8.69655129 -4.87395837]
#  [ 0.08618918 -8.29805847]
#  [-3.74405261 -5.06502053]
#  [-0.63500606 -7.49849147]
#  [ 9.38503255 -4.19322012]
#  [-4.56377588 -5.82874488]
#  [-1.05968582 -8.46874293]]

# %%
import matplotlib.pyplot as plt

plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', s=50)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=200, marker='X')
plt.show()
