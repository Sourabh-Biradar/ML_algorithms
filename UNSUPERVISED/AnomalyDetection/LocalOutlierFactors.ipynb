# %%
# Local Outlier Factor (LOF)

# anomaly detection

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import LocalOutlierFactor
import matplotlib.pyplot as plt

np.random.seed(42)
X_inliers = 0.5 * np.random.randn(100, 2) 
X_inliers = np.r_[X_inliers + 2, X_inliers - 2] 
X_outliers = np.random.uniform(low=-6, high=6, size=(20, 2))  
X = np.r_[X_inliers, X_outliers]

# %%
from sklearn.neighbors import LocalOutlierFactor

model = LocalOutlierFactor(n_neighbors=25,contamination=0.15)

y_pred = model.fit_predict(X)

# %%
lof_score = -model.negative_outlier_factor_

# %%
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=y_pred, cmap='coolwarm', edgecolors='k', s=50)
plt.show()

# %%
lof_score.sort()

lof_score[-10:]     # top 10
# Out:
# array([4.17171734, 4.52686016, 5.03078531, 5.65037869, 5.96637785,
#        6.10528391, 6.19871749, 6.23460752, 6.31353788, 7.88842494])
